# %%
from selenium import webdriver
wd = webdriver.Chrome('driver/chromedriver.exe')
wd.implicitly_wait(2)
wd.get('http://cdn1.python3.vip/files/selenium/test2.html')

# %% [markdown]
# ![%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A52245_2.jpg](attachment:%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A52245_2.jpg)
# ### 如果只想选择“小雷老师”
# + 先把 已经选中的选项全部点击一下，确保都是未选状态
# + 再点击 “小雷老师”

# %%
A = wd.find_elements_by_css_selector('#s_checkbox input[checked="checked"]')
for a in A:
    print('默认选中的是：' + a.get_attribute('value') + '  已经取消勾选')
    a.click()
# Out:
# 默认选中的是：小凯老师  已经取消勾选

# %%
b = wd.find_element_by_css_selector('#s_checkbox input[value="小雷老师"]')
b.click()
