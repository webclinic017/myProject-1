# %%
from selenium import webdriver
wd = webdriver.Chrome('driver/chromedriver.exe')
wd.implicitly_wait(2)
wd.get('https://www.qcc.com/')
element = wd.find_element_by_id('searchkey')
element.send_keys('浙江冠军食品有限公司')

# %% [markdown]
# # 点击元素
# ![%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50026_3.jpg](attachment:%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50026_3.jpg)

# %%
wd.find_element_by_class_name('index-searchbtn').click()

# %% [markdown]
# # 输入字符串
# element.send_keys('白月黑羽')
# # 获取元素的文本
# element.text

# %% [markdown]
# # 获取元素属性
# element.get_attribute('class')
# ![%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50043_4.jpg](attachment:%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50043_4.jpg)

# %%
buttons = wd.find_elements_by_tag_name('button')
print(len(buttons))
a = buttons[0].get_attribute('type')
print(a)
b = buttons[0].get_attribute('class')
print(b)
print(buttons[0].text)
# Out:
# 1
# button
# btn btn-primary
# 查一下

# %% [markdown]
# # 获取整个元素对应的HTML脚本
# element.get_attribute('outerHTML')

# %%
buttons[0].get_attribute('outerHTML')
# Out:
# '<button data-v-363a25ca="" type="button" class="btn btn-primary">查一下</button>'

# %% [markdown]
# # 获取已经输入的文字
# element.get_attribute('value')
# ![%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50053_5.jpg](attachment:%E6%90%9C%E7%8B%97%E6%88%AA%E5%9B%BE21%E5%B9%B408%E6%9C%8825%E6%97%A50053_5.jpg)

# %%
text = wd.find_element_by_id('searchKey')
text.get_attribute('value')
# Out:
# '浙江冠军食品有限公司'

# %% [markdown]
# # 清除输入框
# element.clear()

# %%
text.clear()
text.get_attribute('value')
# Out:
# ''
